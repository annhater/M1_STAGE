# %% [markdown]
# # ASP25 Hydrogen Bond Interaction Analysis for V12 specifically
#
# **What this notebook does:**
# - Reads pre-computed interaction CSV files (one per simulation), each containing a
#   binary column for every detected hydrogen bond (H-bond present → 1, absent → 0)
# - Identifies all H-bonds involving **ASP25** (chain A) or **ASP124** (chain B,
#   the symmetry-equivalent residue)
# - For each simulation, prints which ASP25/124 H-bonds are ever present
# - Provides a quick inspection cell for a specific simulation (V12) and a named bond
#
# **Note:** Use `01_metrics_d25.ipynb` if you need distance-based plots.
#
# **Sections:**
# 1. Install & import libraries
# 2. Configuration
# 3. Helper function: `find_asp_int()`
# 4. Discover interaction files
# 5. Find active ASP25/124 H-bonds per simulation
# 6. Inspect a specific simulation and column

# %%
# 1. Imports
import os
import pandas as pd
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 2. Configuration
ROOTDIR    = '/content/drive/MyDrive/M1_STAGE/Data/interactions/'
OUTPUT_DIR = '/content/drive/MyDrive/M1_STAGE/Manips/'

SIMULATION_LIST = ['res_V1.csv', 'res_V11.csv', 'res_V12.csv',
                   'res_V21.csv', 'res_V7.csv', 'res_V8.csv']

os.chdir(ROOTDIR)

# %%
# 3. Helper function — find ASP25 / ASP124 hydrogen bonds in an interaction file
def find_asp_int(interactions_file: str) -> None:
    """
    Print all H-bond columns involving ASP_25 that have at least one
    non-zero frame in the given CSV.
    """
    df = pd.read_csv(interactions_file)
    hb_asp25_cols = [c for c in df.columns if 'ASP_25' in c and 'hb' in c]
    for col in hb_asp25_cols:
        if df[col].sum() > 0:
            print(f'  {col}')

# %%
# 4. Discover interaction files that exist on disk
interactions_files_paths = []
for name in SIMULATION_LIST:
    full = os.path.join(ROOTDIR, name)
    if os.path.exists(full):
        interactions_files_paths.append(full)
    else:
        print(f'[WARN] {name} not found in {ROOTDIR}')

print(f'Found {len(interactions_files_paths)} interaction file(s).')
# Out:
# Found 6 interaction file(s).

# %%
# 5. Identify active ASP25 / ASP124 H-bonds in each simulation
for interactions_file in interactions_files_paths:
    sim_name = os.path.basename(interactions_file).replace('res_', '').replace('.csv', '')
    print(f'\nSimulation: {sim_name}')
    find_asp_int(interactions_file)
# Out:
# Simulation: V1
#   hbss_ARG_186_NH2_ASP_25_OD2
#   hbsb_ALA_28_N_ASP_25_OD2
#   hbss_ARG_8_NH1_ASP_25_OD2
#   hbsb_ARG_8_N_ASP_25_OD1
#   hbss_ARG_8_NH1_ASP_25_OD1
#   hbsb_ASP_25_OD1_THR_26_N
#   hbss_ARG_186_NH1_ASP_25_OD1
#   hbss_ARG_186_NH2_ASP_25_OD1
#   hbss_ASP_25_OD2_THR_125_OG1
#   hbsb_ALA_28_N_ASP_25_OD1
#   hbss_ASP_25_OD1_THR_125_OG1
#   hbbb_ASP_25_O_GLY_27_N
#   hbsb_ASP_25_OD2_GLY_27_N
#   hbss_ARG_8_NE_ASP_25_OD1
#   hbbb_ALA_28_N_ASP_25_O
#   hbbb_ASP_25_N_PHE_85_O
#   hbbb_ASP_25_N_LEU_23_O
#   hbss_ARG_8_NE_ASP_25_OD2
#   hbbb_ASP_25_N_LEU_24_N
#   hbss_ARG_8_NH2_ASP_25_OD2
#   hbsb_ASP_25_OD2_THR_26_N
#   hbbb_ARG_87_N_ASP_25_O
#   hbss_ARG_8_NH2_ASP_25_OD1
#   hbss_ARG_186_NH1_ASP_25_OD2
#   hbsb_ASP_25_OD1_GLY_27_N
#
# Simulation: V11
#   hbss_ARG_186_NH2_ASP_25_OD2
#   hbsb_ALA_28_N_ASP_25_OD2
#   hbss_ARG_8_NH1_ASP_25_OD2
#   hbss_ARG_8_NH1_ASP_25_OD1
#   hbsb_ASP_25_OD1_THR_26_N
#   hbss_ARG_186_NH1_ASP_25_OD1
#   hbss_ARG_186_NH2_ASP_25_OD1
# ...

# %%
# 6. Inspect a specific bond in V12 — example: H-bonds involving ASP_124
# Adjust the residue ID or bond name as needed
v12_path = os.path.join(ROOTDIR, 'res_V12.csv')
if os.path.exists(v12_path):
    V12_df = pd.read_csv(v12_path)
    asp124_cols = [c for c in V12_df.columns if 'hb' in c and 'ASP_124' in c]
    for col in asp124_cols:
        if V12_df[col].sum() > 0:
            print(f'Active bond: {col}  ({V12_df[col].sum()} frames)')
            print(V12_df.loc[V12_df[col] > 0, [col]].head())
else:
    print('[WARN] res_V12.csv not found.')
# Out:
# Active bond: hbsb_ASP_124_OD1_GLY_126_N  (476 frames)
#    hbsb_ASP_124_OD1_GLY_126_N
# 0                           1
# 1                           1
# 2                           1
# 3                           1
# 5                           1
# Active bond: hbbb_ASP_124_O_GLY_126_N  (134 frames)
#     hbbb_ASP_124_O_GLY_126_N
# 2                          1
# 3                          1
# 15                         1
# 43                         1
# 65                         1
# Active bond: hbsb_ASP_124_OD2_GLY_27_N  (41 frames)
#     hbsb_ASP_124_OD2_GLY_27_N
# 32                          1
# 36                          1
# 37                          1
# 38                          1
# 39                          1
# Active bond: hbsb_ALA_127_N_ASP_124_OD1  (460 frames)
#    hbsb_ALA_127_N_ASP_124_OD1
# 1                           1
# 2                           1
# 3                           1
# 5                           1
# 7                           1
# ...
